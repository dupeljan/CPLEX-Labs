# %%
INP = ['c125.9.txt','keller4.txt','p_hat300_1.txt','brock200_2.txt'][3]

# %%
INP
# Out:
# 'brock200_2.txt'

# %%
Edges = [ str_.split()[1:3] for str_ in open('input/'+INP).readlines() if str_[0] == 'e' ]

# %%
Nodes = list(set([ y for x in Edges for y in x]))

# %%
len(Nodes), len(Edges)
# Out:
# (200, 9876)

# %% [markdown]
# Create the model

# %%
import sys
try:
    import docplex.mp
except:
    if hasattr(sys, 'real_prefix'):
        #we are in a virtual env.
        # !pip3 install docplex
    else:
        # !pip3 install --user docplex

# %%
from docplex.mp.model import Model
from itertools import combinations as comb

cp = Model(name='Max_clique')

# binary varyables for nodes
y = {i : cp.binary_var(name= 'y_{0}'.format(i)) for i in Nodes}



# constrains for clique
for i,j in comb(Nodes,2):
    if [i,j] not in Edges and [j,i] not in Edges:
        cp.add_constraint((y[i] + y[j]) <= 1)

# %%
cp.maximize(cp.sum(y))
cp.print_information()
# Out:
# Model: Max_clique
#  - number of variables: 200
#    - binary=200, integer=0, continuous=0
#  - number of constraints: 10024
#    - linear=10024
#  - parameters: defaults
#  - objective: maximize
#  - problem type is: MILP

# %%
cps= cp.solve(log_output=True)
assert cps
cps.display()
# Out:
# Version identifier: 12.10.0.0 | 2019-11-26 | 843d4de
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_RandomSeed                              201903125
# Found incumbent of value 0.000000 after 0.13 sec. (0.06 ticks)
# Tried aggregator 1 time.
# MIP Presolve eliminated 7099 rows and 0 columns.
# MIP Presolve modified 2925 coefficients.
# Reduced MIP has 2925 rows, 200 columns, and 21384 nonzeros.
# Reduced MIP has 200 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.43 sec. (92.49 ticks)
# Probing time = 0.06 sec. (0.52 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 2925 rows, 200 columns, and 21384 nonzeros.
# Reduced MIP has 200 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.08 sec. (29.98 ticks)
# Probing time = 0.01 sec. (0.67 ticks)
# Clique table members: 2925.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.71 sec. (132.22 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            0.0000      200.0000              ---
# *     0+    0                            7.0000      200.0000              ---
#       0     0       25.5265   176        7.0000       25.5265       18  264.66%
# *     0+    0                           10.0000       25.5265           155.27%
#       0     0       23.6445   176       10.0000     Cuts: 161     1650  136.45%
#       0     0       23.4446   176       10.0000      Cuts: 25     1919  134.45%
#       0     0       23.3092   176       10.0000   Cliques: 12     2085  133.09%
#       0     0       23.2289   176       10.0000    Cliques: 9     2207  132.29%
#       0     0       23.1557   176       10.0000    Cliques: 9     2326  131.56%
# Detecting symmetries...
#       0     0       23.0812   176       10.0000    Cliques: 8     2462  130.81%
#       0     0       23.0012   176       10.0000    Cliques: 8     2566  130.01%
#       0     0       22.9407   176       10.0000    Cliques: 8     2677  129.41%
#       0     0       22.6515   176       10.0000   Cliques: 32     2974  126.51%
#       0     0       22.5213   176       10.0000   Cliques: 24     3130  125.21%
#       0     0       22.4343   176       10.0000   Cliques: 19     3296  124.34%
#       0     0       22.3929   176       10.0000    Cliques: 7     3384  123.93%
#       0     0       22.3690   176       10.0000    Cliques: 8     3458  123.69%
#       0     0       22.3346   176       10.0000    Cliques: 9     3541  123.35%
#       0     0       22.3231   176       10.0000    Cliques: 6     3594  123.23%
#       0     0       22.3124   176       10.0000    Cliques: 5     3646  123.12%
#       0     0       22.3100   176       10.0000    Cliques: 1     3672  111.03%
#       0     0       22.3026   176       10.0000    Cliques: 1     3705   99.82%
# Detecting symmetries...
#       0     2       22.3026   200       10.0000       19.9820     3705   99.82%
# Elapsed time = 23.82 sec. (11806.96 ticks, tree = 0.02 MB, solutions = 3)
#      49     8       12.8439    44       10.0000       19.9820     5726   99.82%
#     200    21        cutoff             10.0000       19.9820    10509   99.82%
#     290    33       12.7708    45       10.0000       19.9820    14126   99.82%
#     409   120       11.8176    50       10.0000       19.9820    21215   99.82%
#     544   204        cutoff             10.0000       19.9820    27015   99.82%
#     708   322        cutoff             10.0000       19.9820    35100   99.82%
#     895   451        cutoff             10.0000       19.9820    42597   99.82%
#    1100   510        cutoff             10.0000       19.9820    49100   99.82%
#    1275   538        cutoff             10.0000       19.9820    54277   99.82%
#    1634   818       15.5694    81       10.0000       19.9820    76995   99.82%
# Elapsed time = 29.90 sec. (14921.06 ticks, tree = 17.73 MB, solutions = 3)
#    2079  1178       15.6690    81       10.0000       19.9820   101656   99.82%
#
# Performing restart 1
#
# Repeating presolve.
# Tried aggregator 1 time.
# Reduced MIP has 2925 rows, 200 columns, and 21384 nonzeros.
# Reduced MIP has 200 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.08 sec. (28.87 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2925 rows, 200 columns, and 21384 nonzeros.
# Reduced MIP has 200 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.10 sec. (30.32 ticks)
# Represolve time = 0.34 sec. (76.18 ticks)
#    2384     0       22.1513   198       10.0000       Cuts: 5   124434   99.82%
#    2384     0       22.1258   198       10.0000       Cuts: 5   124513   99.82%
#    2384     0       22.1014   198       10.0000       Cuts: 5   124612   99.82%
#    2384     0       22.0842   198       10.0000      Cuts: 12   124688   99.82%
#    2384     0       22.0741   198       10.0000       Cuts: 4   124756   99.82%
#    2384     2       22.0741   196       10.0000       19.9820   124756   99.82%
#    2496    26       16.2176    84       10.0000       19.9820   130467   99.82%
# *  2646   107      integral     0       12.0000       19.9820   139078   66.52%
#    2815   135       13.4410    64       12.0000       19.9820   149007   66.52%
#    3137   326       15.3170    75       12.0000       19.9820   166670   66.52%
#    3561   657       14.1962    69       12.0000       19.9820   190779   66.52%
#    3869   886       14.9691    71       12.0000       19.9820   211219   66.52%
#    4322  1171       13.4170    57       12.0000       19.6194   235577   63.50%
#    4585  1255       13.0597    45       12.0000       18.1325   256088   51.10%
#    4922  1277       14.3252    65       12.0000       16.6180   278479   38.48%
# Elapsed time = 60.75 sec. (29778.72 ticks, tree = 20.10 MB, solutions = 4)
#    5217  1121        cutoff             12.0000       15.8834   307832   32.36%
#    5641   686        cutoff             12.0000       14.5652   342010   21.38%
#
# Clique cuts applied:  181
# Gomory fractional cuts applied:  5
#
# Root node processing (before b&c):
#   Real time             =   23.74 sec. (11802.80 ticks)
# Parallel b&c, 4 threads:
#   Real time             =   42.15 sec. (20357.74 ticks)
#   Sync time (average)   =    3.34 sec.
#   Wait time (average)   =    0.28 sec.
#                           ------------
# Total (root+branch&cut) =   65.89 sec. (32160.55 ticks)
# solution for: Max_clique
# objective: 12
# y_121 = 1
# y_183 = 1
# y_158 = 1
# y_70 = 1
# y_55 = 1
# y_149 = 1
# y_120 = 1
# y_105 = 1
# y_27 = 1
# y_48 = 1
# y_145 = 1
# y_135 = 1

# %%
cps.display()
# Out:
# solution for: Max_clique
# objective: 12
# y_121 = 1
# y_183 = 1
# y_158 = 1
# y_70 = 1
# y_55 = 1
# y_149 = 1
# y_120 = 1
# y_105 = 1
# y_27 = 1
# y_48 = 1
# y_145 = 1
# y_135 = 1

# %%
dir(cps)
# Out:
# ['NO_OBJECTIVE_VALUE',
#  '__as_df__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_basis_statuses',
#  '_blended_objective_by_priority',
#  '_checker',
#  '_dual_values',
#  '_export_as_string',
#  '_get_status',
#  '_get_values',
#  '_get_var_by_name',
#  '_get_var_value',
#  '_has_basis',
#  '_infeasibilities',
#  '_is_discrete_value',
#  '_keep_zeros',
#  '_model',
#  '_name',
#  '_objective',
#  '_problem_objective_expr',
#  '_problem_objective_name',
#  '_reduced_costs',
#  '_resolve_attribute_index_map',
#  '_resolve_var',
#  '_set_solve_status',
#  '_set_var_key_value',
#  '_set_var_value',
#  '_set_var_value_internal',
#  '_slack_values',
#  '_solve_details',
#  '_solve_status',
#  '_solved_by',
#  '_store_var_value_map',
#  '_typecheck_var_key_value',
#  '_var_value_map',
#  'add_var_value',
#  'as_df',
#  'as_dict',
#  'as_mip_start',
#  'as_name_dict',
#  'blended_objective_values',
#  'check_as_mip_start',
#  'clear',
#  'contains',
#  'display',
#  'display_attributes',
#  'ensure_basis_statuses',
#  'ensure_dual_values',
#  'ensure_reduced_costs',
#  'ensure_slack_values',
#  'equals_solution',
#  'export',
#  'export_as_json_string',
#  'export_as_mst',
#  'export_as_mst_string',
#  'find_invalid_domain_variables',
#  'find_unsatisfied_constraints',
#  'get_all_values',
#  'get_blended_objective_value_by_priority',
#  'get_dual_values',
#  'get_infeasibility',
#  'get_linearct_basis_statuses',
#  'get_name',
#  'get_objective_value',
#  'get_printer',
#  'get_reduced_costs',
#  'get_slacks',
#  'get_status',
#  'get_value',
#  'get_value_df',
#  'get_value_dict',
#  'get_value_list',
#  'get_values',
#  'get_var_basis_statuses',
#  'get_var_value',
#  'has_basis',
#  'has_objective',
#  'is_empty',
#  'is_feasible_solution',
#  'is_valid_solution',
#  'iter_var_values',
#  'iter_variables',
#  'iteritems',
#  'kpi_value_by_name',
#  'make_engine_solution',
#  'model',
#  'multi_objective_values',
#  'name',
#  'number_of_var_values',
#  'objective_value',
#  'print_mst',
#  'problem_name',
#  'restore',
#  'set_name',
#  'set_objective_value',
#  'set_var_key_value',
#  'solve_details',
#  'solve_status',
#  'solved_by',
#  'store_dual_values',
#  'store_infeasibilities',
#  'store_reduced_costs',
#  'store_slack_values',
#  'to_string',
#  'to_stringio',
#  'update']

# %%
help(cps.get_value_dict)
# Out:
# Help on method get_value_dict in module docplex.mp.solution:
#
# get_value_dict(var_dict, keep_zeros=True, precision=0) method of docplex.mp.solution.SolveSolution instance
#     Converts a dictionary of variables to a dictionary of solutions
#
#     Assuming `var_dict` is a dictionary of variables
#     (for example, as returned by `Model.integer_var_dict()`,
#     returns a dictionary with the same keys and as values the solution values of the
#     variables.
#
#     :param var_dict: a dictionary of decision variables.
#     :param keep_zeros: an optional flag to keep zero values (default is True)
#     :param precision: an optional precision, used when filtering out zero values. The default is 1e-6.
#         When keep_zeros is False, all values smaller than this value are left out.
#
#     :return: A dictionary from variable keys to solution values (floats).

# %%
list(zip(Nodes,cps.get_all_values()))
# Out:
# [('179', 0),
#  ('157', 0),
#  ('63', 0),
#  ('51', 0),
#  ('143', 0),
#  ('121', 1.0),
#  ('136', 0),
#  ('172', 0),
#  ('187', 0),
#  ('189', 0),
#  ('183', 1),
#  ('78', 0),
#  ('91', 0),
#  ('158', 1.0),
#  ('56', 0),
#  ('192', 0),
#  ('97', 0),
#  ('2', 0),
#  ('80', 0),
#  ('41', 0),
#  ('164', 0),
#  ('194', 0),
#  ('57', 0),
#  ('193', 0),
#  ('109', 0),
#  ('110', 0),
#  ('167', 0),
#  ('141', 0),
#  ('126', 0),
#  ('112', 0),
#  ('11', 0),
#  ('74', 0),
#  ('81', 0),
#  ('98', 0),
#  ('61', 0),
#  ('132', 0),
#  ('170', 0),
#  ('18', 0),
#  ('13', 0),
#  ('94', 0),
#  ('163', 0),
#  ('44', 0),
#  ('95', 0),
#  ('16', 0),
#  ('191', 0),
#  ('188', 0),
#  ('171', 0),
#  ('47', 0),
#  ('199', 0),
#  ('52', 0),
#  ('38', 0),
#  ('46', 0),
#  ('92', 0),
#  ('45', 0),
#  ('79', 0),
#  ('70', 1),
#  ('5', 0),
#  ('55', 1.0),
#  ('28', 0),
#  ('39', 0),
#  ('65', 0),
#  ('155', 0),
#  ('174', 0),
#  ('49', 0),
#  ('96', 0),
#  ('58', 0),
#  ('104', 0),
#  ('177', 0),
#  ('64', 0),
#  ('29', 0),
#  ('54', 0),
#  ('134', 0),
#  ('162', 0),
#  ('133', 0),
#  ('68', 0),
#  ('182', 0),
#  ('76', 0),
#  ('184', 0),
#  ('90', 0),
#  ('147', 0),
#  ('60', 0),
#  ('185', 0),
#  ('7', 0),
#  ('10', 0),
#  ('20', 0),
#  ('86', 0),
#  ('124', 0),
#  ('6', 0),
#  ('149', 1.0),
#  ('120', 1.0),
#  ('108', 0),
#  ('14', 0),
#  ('15', 0),
#  ('26', 0),
#  ('106', 0),
#  ('122', 0),
#  ('180', 0),
#  ('23', 0),
#  ('168', 0),
#  ('102', 0),
#  ('99', 0),
#  ('175', 0),
#  ('9', 0),
#  ('42', 0),
#  ('125', 0),
#  ('119', 0),
#  ('169', 0),
#  ('24', 0),
#  ('101', 0),
#  ('148', 0),
#  ('118', 0),
#  ('17', 0),
#  ('66', 0),
#  ('22', 0),
#  ('105', 1.0),
#  ('131', 0),
#  ('117', 0),
#  ('12', 0),
#  ('40', 0),
#  ('67', 0),
#  ('34', 0),
#  ('111', 0),
#  ('130', 0),
#  ('139', 0),
#  ('19', 0),
#  ('166', 0),
#  ('25', 0),
#  ('129', 0),
#  ('77', 0),
#  ('200', 0),
#  ('196', 0),
#  ('116', 0),
#  ('153', 0),
#  ('36', 0),
#  ('30', 0),
#  ('85', 0),
#  ('127', 0),
#  ('27', 1.0),
#  ('142', 0),
#  ('140', 0),
#  ('59', 0),
#  ('197', 0),
#  ('113', 0),
#  ('72', 0),
#  ('137', 0),
#  ('146', 0),
#  ('32', 0),
#  ('103', 0),
#  ('48', 1.0),
#  ('31', 0),
#  ('186', 0),
#  ('84', 0),
#  ('33', 0),
#  ('145', 1.0),
#  ('1', 0),
#  ('160', 0),
#  ('88', 0),
#  ('93', 0),
#  ('100', 0),
#  ('128', 0),
#  ('165', 0),
#  ('176', 0),
#  ('178', 0),
#  ('152', 0),
#  ('43', 0),
#  ('107', 0),
#  ('195', 0),
#  ('181', 0),
#  ('89', 0),
#  ('82', 0),
#  ('73', 0),
#  ('35', 0),
#  ('71', 0),
#  ('123', 0),
#  ('150', 0),
#  ('159', 0),
#  ('50', 0),
#  ('190', 0),
#  ('62', 0),
#  ('37', 0),
#  ('4', 0),
#  ('83', 0),
#  ('114', 0),
#  ('115', 0),
#  ('138', 0),
#  ('198', 0),
#  ('154', 0),
#  ('53', 0),
#  ('151', 0),
#  ('87', 0),
#  ('144', 0),
#  ('173', 0),
#  ('135', 1.0),
#  ('69', 0),
#  ('161', 0),
#  ('3', 0),
#  ('21', 0),
#  ('8', 0),
#  ('75', 0),
#  ('156', 0)]

# %%
all_values = { n : val for n,val  in list(zip(Nodes,cps.get_all_values())) }
pos_values = { n : val for n, val in all_values.items() if val == 1  }

pos_values, cps.get_objective_value()
# Out:
# ({'121': 1.0,
#   '183': 1,
#   '158': 1.0,
#   '70': 1,
#   '55': 1.0,
#   '149': 1.0,
#   '120': 1.0,
#   '105': 1.0,
#   '27': 1.0,
#   '48': 1.0,
#   '145': 1.0,
#   '135': 1.0},
#  12.0)

# %%
dir(cp)
# Out:
# ['DEFAULT_OBJECTIVE_FMT',
#  'DEFAULT_VAR_VALUE_QUOTED_SOLUTION_FMT',
#  'DEFAULT_VAR_VALUE_UNQUOTED_SOLUTION_FMT',
#  '_Model__all_implicit_equiv_cts',
#  '_Model__allcts',
#  '_Model__allpwlfuncs',
#  '_Model__allvarctns',
#  '_Model__allvars',
#  '_Model__engine',
#  '_Model__notify_new_model_object',
#  '_Model__notify_new_var',
#  '_Model__vars_by_name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_batch_logical_cts',
#  '_add_constraint_internal',
#  '_add_indicator',
#  '_add_progress_listener',
#  '_add_pwl_constraint_internal',
#  '_add_pwl_expr',
#  '_add_solve_hook',
#  '_add_sos',
#  '_add_var_container',
#  '_aggregator',
#  '_allkpis',
#  '_allsos',
#  '_apply_parameters_to_engine',
#  '_benders_annotations',
#  '_binary_vartype',
#  '_can_solve',
#  '_check_basis',
#  '_check_mip_for_mipstarts',
#  '_check_name',
#  '_check_solved_as_mip',
#  '_checker',
#  '_checker_key',
#  '_clean_before_solve',
#  '_clear_cached_discrete_var',
#  '_clear_internal',
#  '_clear_multi_objective',
#  '_clear_objective_expr',
#  '_clear_scopes',
#  '_compile_multiobj_expr_list',
#  '_connect_progress_listeners',
#  '_constraint_priority_dict',
#  '_contains_discrete_artefacts',
#  '_continuous_vartype',
#  '_count_constraints_filtered',
#  '_count_constraints_with_type',
#  '_count_variables_w_code',
#  '_create_engine_constraint',
#  '_create_engine_sos',
#  '_cts_by_name',
#  '_ctscopes',
#  '_default_effort_level',
#  '_disconnect_progress_listeners',
#  '_dual_value1',
#  '_dual_values',
#  '_engine_factory',
#  '_ensure_benders_annotations',
#  '_ensure_cts_name_dir',
#  '_environment',
#  '_error_handler',
#  '_export',
#  '_export_as_cplex_string',
#  '_export_to_path',
#  '_export_to_stream',
#  '_extend_constraint_section',
#  '_find_matching_objs',
#  '_fire_end_solve_listeners',
#  '_fire_start_solve_listeners',
#  '_float_meta_format',
#  '_float_precision',
#  '_generate_sos',
#  '_generic_get_basis_status',
#  '_get_cplex_engine',
#  '_get_cplex_problem_type',
#  '_get_kwargs',
#  '_get_non_ambiguous_varname',
#  '_get_printer',
#  '_get_solution',
#  '_get_sos_by_index',
#  '_has_piecewise',
#  '_has_solution',
#  '_has_username_with_spaces',
#  '_ignore_names',
#  '_indicator_trivial_feasible_idx',
#  '_indicator_trivial_infeasible_idx',
#  '_integer_vartype',
#  '_is_binary_var',
#  '_is_continuous_var',
#  '_is_cplex_ce',
#  '_is_empty',
#  '_is_integer_var',
#  '_is_lazy_constraint',
#  '_is_semicontinuous_var',
#  '_is_semiinteger_var',
#  '_is_user_cut_constraint',
#  '_iter_all_logical_constraints',
#  '_iter_variables_w_code',
#  '_keep_all_exprs',
#  '_keep_ordering',
#  '_last_solve_status',
#  '_lazy_constraints',
#  '_lazy_get_environment',
#  '_lfactory',
#  '_linct_scope',
#  '_linearct_basis_status',
#  '_logical_scope',
#  '_lp_line_length',
#  '_make_end_infodict',
#  '_make_environment',
#  '_make_lex_priorities',
#  '_make_new_engine_from_agent',
#  '_make_output_path',
#  '_max_repr_len',
#  '_mipstarts',
#  '_multi_objective',
#  '_multi_objective_values',
#  '_name',
#  '_name_generator',
#  '_new_default_objective_expr',
#  '_new_docloud_engine',
#  '_notify_solve_hit_limit',
#  '_notify_trivial_constraint',
#  '_num_printer',
#  '_numpy_print_str',
#  '_objective_coef',
#  '_objective_expr',
#  '_objective_sense',
#  '_objective_value',
#  '_parse_kwargs',
#  '_piecewise',
#  '_post_constraint',
#  '_prepare_constraint',
#  '_print_full_obj',
#  '_progress_listeners',
#  '_pwl_counter',
#  '_pwl_scope',
#  '_qfactory',
#  '_quadct_scope',
#  '_quality_metrics',
#  '_read_cplex_file',
#  '_reduced_cost1',
#  '_reduced_costs',
#  '_register_block_cts',
#  '_register_block_vars',
#  '_register_ct_name',
#  '_register_implicit_equivalence_ct',
#  '_register_one_constraint',
#  '_register_one_pwl_constraint',
#  '_register_one_var',
#  '_register_sos',
#  '_remove_constraint_internal',
#  '_remove_constraints_internal',
#  '_report_lexicographic_goals',
#  '_reported_objective_value',
#  '_resolve_ct',
#  '_resolve_path',
#  '_resolve_sense',
#  '_resync',
#  '_round_element_value_if_necessary',
#  '_round_function',
#  '_round_solution',
#  '_saved_numpy_options',
#  '_scopes',
#  '_semicontinuous_vartype',
#  '_semiinteger_vartype',
#  '_set_engine',
#  '_set_engine_multi_objective_exprs',
#  '_set_lex_multi_objective',
#  '_set_multi_objective_exprs',
#  '_set_multi_objective_internal',
#  '_set_solution',
#  '_set_var_lb',
#  '_set_var_type',
#  '_set_var_ub',
#  '_slack_value1',
#  '_slack_values',
#  '_solution',
#  '_solve_cloud',
#  '_solve_details',
#  '_solve_hooks',
#  '_solve_local',
#  '_solved_as_lp',
#  '_solved_as_mip',
#  '_supports_logical_constraints',
#  '_supports_multi_objective',
#  '_sync_constraint_indices',
#  '_sync_params',
#  '_sync_var_indices',
#  '_synced_params',
#  '_terminate_engine',
#  '_trivial_cts_message_level',
#  '_typecheck_optional_num_seq',
#  '_unknown_status',
#  '_update_var_bounds_from_type',
#  '_user_cuts',
#  '_var',
#  '_var_basis_status',
#  '_var_basis_status1',
#  '_var_by_index',
#  '_var_dict',
#  '_var_scope',
#  '_vartypes',
#  '_write_cplex_file',
#  'abs',
#  'add',
#  'add_',
#  'add_constraint',
#  'add_constraint_',
#  'add_constraints',
#  'add_constraints_',
#  'add_equivalence',
#  'add_equivalence_constraints',
#  'add_equivalence_constraints_',
#  'add_equivalences',
#  'add_if_then',
#  'add_indicator',
#  'add_indicator_constraints',
#  'add_indicator_constraints_',
#  'add_indicators',
#  'add_kpi',
#  'add_lazy_constraint',
#  'add_lazy_constraints',
#  'add_mip_start',
#  'add_piecewise_constraint',
#  'add_progress_listener',
#  'add_range',
#  'add_ranges',
#  'add_sos',
#  'add_sos1',
#  'add_sos2',
#  'add_user_cut_constraint',
#  'add_user_cut_constraints',
#  'apply_one_parameter',
#  'apply_parameters',
#  'binary_var',
#  'binary_var_cube',
#  'binary_var_dict',
#  'binary_var_list',
#  'binary_var_matrix',
#  'binary_vartype',
#  'blended_objective_values',
#  'cannot_be_used_as_denominator_error',
#  'check_has_solution',
#  'check_logical_constraint_support',
#  'check_multi_objective_support',
#  'check_problem_type',
#  'clean_before_solve',
#  'clear',
#  'clear_benders_annotations',
#  'clear_constraints',
#  'clear_kpis',
#  'clear_lazy_constraints',
#  'clear_mip_starts',
#  'clear_multi_objective',
#  'clear_progress_listeners',
#  'clear_sos',
#  'clear_user_cut_constraints',
#  'clone',
#  'context',
#  'continuous_var',
#  'continuous_var_cube',
#  'continuous_var_dict',
#  'continuous_var_list',
#  'continuous_var_matrix',
#  'continuous_vartype',
#  'copy',
#  'cplex',
#  'dot',
#  'dotf',
#  'dual_values',
#  'dump',
#  'dump_as_lp',
#  'enable_cts_by_name_dict',
#  'end',
#  'ensure_setup',
#  'environment',
#  'eq_constraint',
#  'equivalence_constraint',
#  'error',
#  'error_handler',
#  'export',
#  'export_annotations',
#  'export_as_lp',
#  'export_as_lp_string',
#  'export_as_mps',
#  'export_as_mps_string',
#  'export_as_sav',
#  'export_as_sav_string',
#  'export_basis',
#  'export_parameters_as_prm',
#  'export_priority_order_file',
#  'export_to_stream',
#  'export_to_string',
#  'fatal',
#  'fatal_ce_limits',
#  'find_matching_linear_constraints',
#  'find_matching_vars',
#  'find_re_matching_vars',
#  'fire_jobid',
#  'fire_progress',
#  'float_precision',
#  'ge_constraint',
#  'gen_constraints_with_type',
#  'generate_user_linear_constraints',
#  'generate_user_variables',
#  'get_annotation_stats',
#  'get_annotations_by_scope',
#  'get_benders_annotation',
#  'get_constraint_by_index',
#  'get_constraint_by_name',
#  'get_constraint_priority',
#  'get_cplex',
#  'get_engine',
#  'get_engine_parameter_value',
#  'get_hidden_parameter',
#  'get_logical_constraint_by_index',
#  'get_name',
#  'get_objective_expr',
#  'get_parameter_from_id',
#  'get_quadratic_constraint_by_index',
#  'get_solve_details',
#  'get_solve_status',
#  'get_statistics',
#  'get_time_limit',
#  'get_var_by_index',
#  'get_var_by_name',
#  'has_basis',
#  'has_benders_annotations',
#  'has_cplex',
#  'has_cts_by_name_dict',
#  'has_multi_objective',
#  'has_objective',
#  'has_quadratic_constraint',
#  'if_then',
#  'ignore_names',
#  'indicator_constraint',
#  'infinity',
#  'info',
#  'init_numpy',
#  'integer_var',
#  'integer_var_cube',
#  'integer_var_dict',
#  'integer_var_list',
#  'integer_var_matrix',
#  'integer_vartype',
#  'is_cplex_ce',
#  'is_logged',
#  'is_maximized',
#  'is_minimized',
#  'is_optimized',
#  'iter_benders_annotations',
#  'iter_binary_constraints',
#  'iter_binary_vars',
#  'iter_constraints',
#  'iter_continuous_vars',
#  'iter_equivalence_constraints',
#  'iter_implicit_equivalence_cts',
#  'iter_indicator_constraints',
#  'iter_integer_vars',
#  'iter_kpis',
#  'iter_lazy_constraints',
#  'iter_linear_constraints',
#  'iter_logical_constraints',
#  'iter_mip_starts',
#  'iter_multi_objective_exprs',
#  'iter_multi_objective_tuples',
#  'iter_progress_listeners',
#  'iter_pwl_constraints',
#  'iter_pwl_functions',
#  'iter_quadratic_constraints',
#  'iter_range_constraints',
#  'iter_semicontinuous_vars',
#  'iter_semiinteger_vars',
#  'iter_sos',
#  'iter_sos1',
#  'iter_sos2',
#  'iter_user_cut_constraints',
#  'iter_var_containers',
#  'iter_variables',
#  'keep_ordering',
#  'kpi_by_name',
#  'kpi_value_by_name',
#  'kpis_as_dict',
#  'le_constraint',
#  'linear_constraint',
#  'linear_constraint_basis_statuses',
#  'linear_expr',
#  'log_output',
#  'logger',
#  'logical_and',
#  'logical_not',
#  'logical_or',
#  'lp_format',
#  'lp_line_length',
#  'lp_string',
#  'max',
#  'max_repr_len',
#  'maximize',
#  'maximize_static_lex',
#  'min',
#  'minimize',
#  'minimize_static_lex',
#  'mip_starts',
#  'multi_objective_values',
#  'name',
#  'new_solution',
#  'not_equal_constraint',
#  'notify_expr_modified',
#  'notify_expr_replaced',
#  'notify_solve_failed',
#  'notify_solve_relaxed',
#  'notify_start_solve',
#  'number_of_binary_variables',
#  'number_of_constraints',
#  'number_of_continuous_variables',
#  'number_of_equivalence_constraints',
#  'number_of_generated_variables',
#  'number_of_implicit_equivalences',
#  'number_of_indicator_constraints',
#  'number_of_integer_variables',
#  'number_of_kpis',
#  'number_of_lazy_constraints',
#  'number_of_linear_constraints',
#  'number_of_mip_starts',
#  'number_of_multi_objective_exprs',
#  'number_of_nonzeros',
#  'number_of_progress_listeners',
#  'number_of_pwl_constraints',
#  'number_of_quadratic_constraints',
#  'number_of_range_constraints',
#  'number_of_semicontinuous_variables',
#  'number_of_semiinteger_variables',
#  'number_of_sos',
#  'number_of_sos1',
#  'number_of_sos2',
#  'number_of_user_cut_constraints',
#  'number_of_user_variables',
#  'number_of_variables',
#  'objective_coef',
#  'objective_expr',
#  'objective_sense',
#  'objective_value',
#  'output_level',
#  'parameters',
#  'parse_vartype',
#  'piecewise',
#  'piecewise_as_slopes',
#  'pop_constraint',
#  'pprint',
#  'pprint_as_string',
#  'prepare_actual_context',
#  'prettyprint',
#  'print_information',
#  'print_solution',
#  'progress_listeners',
#  'quad_expr',
#  'quadratic_dual_slacks',
#  'quality_metrics',
#  'range_constraint',
#  'read_basis_file',
#  'read_mip_starts',
#  'read_priority_order_file',
#  'reduced_costs',
#  'refresh_model',
#  'register_callback',
#  'remove',
#  'remove_benders_annotation',
#  'remove_constraint',
#  'remove_constraints',
#  'remove_kpi',
#  'remove_mip_start',
#  'remove_objective',
#  'remove_progress_listener',
#  'report',
#  'report_kpis',
#  'resolve',
#  'restore_numpy',
#  'restore_solution',
#  'round_solution',
#  'scal_prod',
#  'scal_prod_f',
#  'semicontinuous_var',
#  'semicontinuous_var_dict',
#  'semicontinuous_var_list',
#  'semicontinuous_var_matrix',
#  'semicontinuous_vartype',
#  'semiinteger_var',
#  'semiinteger_var_dict',
#  'semiinteger_var_list',
#  'semiinteger_var_matrix',
#  'semiinteger_vartype',
#  'set_benders_annotation',
#  'set_checker',
#  'set_constraint_priority',
#  'set_hidden_parameter',
#  'set_lex_multi_objective',
#  'set_linear_constraint_name',
#  'set_log_output',
#  'set_log_output_as_stream',
#  'set_lp_start_basis',
#  'set_multi_objective',
#  'set_multi_objective_exprs',
#  'set_new_engine_from_agent',
#  'set_objective',
#  'set_objective_expr',
#  'set_objective_sense',
#  'set_quiet',
#  'set_time_limit',
#  'set_var_lb',
#  'set_var_name',
#  'set_var_ub',
#  'setup',
#  'slack_values',
#  'solution',
#  'solve',
#  'solve_cloud',
#  'solve_details',
#  'solve_lexicographic',
#  'solve_status',
#  'solved_stopped_by_limit',
#  'solver_agent',
#  'solves_as_qxp',
#  'solves_with',
#  'statistics',
#  'sum',
#  'sum_squares',
#  'sum_vars',
#  'sum_vars_all_different',
#  'sumsq',
#  'supports_logical_constraints',
#  'supports_multi_objective',
#  'time_limit',
#  'time_limit_parameter',
#  'trace',
#  'typecheck_as_denominator',
#  'typecheck_as_power',
#  'typecheck_num',
#  'typecheck_var',
#  'unsupported_relational_operator_error',
#  'var',
#  'var_basis_statuses',
#  'var_dict',
#  'var_list',
#  'var_matrix',
#  'var_multidict',
#  'warn_trivial_feasible',
#  'warn_trivial_infeasible',
#  'warn_trivial_none',
#  'warning']

# %%
import networkx as nx 
G = nx.Graph()
INP = ['c125.9.txt','keller4.txt','p_hat300_1.txt','brock200_2.txt'][3]
Edges = [ list(map( int, str_.split()[1:3])) for str_ in open('input/'+INP).readlines() if str_[0] == 'e' ]
G.add_edges_from(Edges)
