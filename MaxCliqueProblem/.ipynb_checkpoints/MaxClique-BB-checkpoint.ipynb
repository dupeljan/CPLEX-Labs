# %%
INP = ['c125.9.txt','keller4.txt','p_hat300_1.txt','brock200_2.txt'][3]

# %%
INP
# Out:
# 'brock200_2.txt'

# %%
Edges = [ str_.split()[1:3] for str_ in open('input/'+INP).readlines() if str_[0] == 'e' ]

# %%
Nodes = list(set([ y for x in Edges for y in x]))

# %%
len(Nodes), len(Edges)
# Out:
# (200, 9876)

# %% [markdown]
# Create the model

# %%
import sys
try:
    import docplex.mp
except:
    if hasattr(sys, 'real_prefix'):
        #we are in a virtual env.
        # !pip3 install docplex
    else:
        # !pip3 install --user docplex

# %%
from docplex.mp.model import Model
from itertools import combinations as comb

cp = Model(name='Max_clique')

# binary varyables for nodes
y = {i : cp.continuous_var(name= 'y_{0}'.format(i)) for i in Nodes}

# y constrains
y_cons = { n : cp.add_constraint( y[n] <= 1) for n in Nodes }


# constrains for clique
for i,j in comb(Nodes,2):
    if [i,j] not in Edges and [j,i] not in Edges:
        cp.add_constraint((y[i] + y[j]) <= 1)

# %% [markdown]
# Create objective

# %%
cp.maximize(cp.sum(y))
cp.print_information()
# Out:
# Model: Max_clique
#  - number of variables: 200
#    - binary=0, integer=0, continuous=200
#  - number of constraints: 10224
#    - linear=10224
#  - parameters: defaults
#  - objective: maximize
#  - problem type is: LP

# %%
cps= cp.solve(log_output=True)
assert cps
cps.display()
# Out:
# Version identifier: 12.10.0.0 | 2019-11-26 | 843d4de
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_RandomSeed                              201903125
# Parallel mode: deterministic, using up to 4 threads for concurrent optimization:
#  * Starting dual Simplex on 1 thread...
#  * Starting Barrier on 3 threads...
# Tried aggregator 1 time.
# LP Presolve eliminated 200 rows and 0 columns.
# Reduced LP has 10024 rows, 200 columns, and 20048 nonzeros.
# Presolve time = 0.12 sec. (6.03 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual objective     =           199.000000
# Iteration:   237   Dual objective     =           176.000000
# Perturbation started.
# Iteration:   357   Dual objective     =           167.500000
# Removing perturbation.
#
# Dual simplex solved model.
#
# solution for: Max_clique
# objective: 100.000
# y_72 = 0.500
# y_127 = 0.500
# y_66 = 0.500
# y_20 = 0.500
# y_153 = 0.500
# y_165 = 0.500
# y_55 = 0.500
# y_50 = 0.500
# y_192 = 0.500
# y_88 = 0.500
# y_185 = 0.500
# y_10 = 0.500
# y_200 = 0.500
# y_31 = 0.500
# y_11 = 0.500
# y_117 = 0.500
# y_148 = 0.500
# y_9 = 0.500
# y_63 = 0.500
# y_4 = 0.500
# y_115 = 0.500
# y_197 = 0.500
# y_89 = 0.500
# y_138 = 0.500
# y_118 = 0.500
# y_71 = 0.500
# y_57 = 0.500
# y_74 = 0.500
# y_177 = 0.500
# y_39 = 0.500
# y_172 = 0.500
# y_140 = 0.500
# y_53 = 0.500
# y_161 = 0.500
# y_94 = 0.500
# y_178 = 0.500
# y_85 = 0.500
# y_5 = 0.500
# y_139 = 0.500
# y_163 = 0.500
# y_155 = 0.500
# y_22 = 0.500
# y_62 = 0.500
# y_144 = 0.500
# y_78 = 0.500
# y_21 = 0.500
# y_61 = 0.500
# y_49 = 0.500
# y_105 = 0.500
# y_135 = 0.500
# y_141 = 0.500
# y_16 = 0.500
# y_154 = 0.500
# y_111 = 0.500
# y_176 = 0.500
# y_41 = 0.500
# y_184 = 0.500
# y_12 = 0.500
# y_175 = 0.500
# y_145 = 0.500
# y_151 = 0.500
# y_169 = 0.500
# y_101 = 0.500
# y_194 = 0.500
# y_30 = 0.500
# y_38 = 0.500
# y_48 = 0.500
# y_190 = 0.500
# y_17 = 0.500
# y_87 = 0.500
# y_65 = 0.500
# y_73 = 0.500
# y_32 = 0.500
# y_46 = 0.500
# y_195 = 0.500
# y_109 = 0.500
# y_79 = 0.500
# y_69 = 0.500
# y_58 = 0.500
# y_132 = 0.500
# y_99 = 0.500
# y_157 = 0.500
# y_26 = 0.500
# y_70 = 0.500
# y_67 = 0.500
# y_40 = 0.500
# y_162 = 0.500
# y_189 = 0.500
# y_166 = 0.500
# y_51 = 0.500
# y_112 = 0.500
# y_121 = 0.500
# y_136 = 0.500
# y_93 = 0.500
# y_3 = 0.500
# y_80 = 0.500
# y_120 = 0.500
# y_188 = 0.500
# y_15 = 0.500
# y_76 = 0.500
# y_83 = 0.500
# y_199 = 0.500
# y_24 = 0.500
# y_104 = 0.500
# y_108 = 0.500
# y_119 = 0.500
# y_82 = 0.500
# y_146 = 0.500
# y_159 = 0.500
# y_52 = 0.500
# y_36 = 0.500
# y_147 = 0.500
# y_42 = 0.500
# y_156 = 0.500
# y_6 = 0.500
# y_18 = 0.500
# y_193 = 0.500
# y_116 = 0.500
# y_91 = 0.500
# y_47 = 0.500
# y_68 = 0.500
# y_23 = 0.500
# y_103 = 0.500
# y_126 = 0.500
# y_133 = 0.500
# y_174 = 0.500
# y_129 = 0.500
# y_86 = 0.500
# y_137 = 0.500
# y_182 = 0.500
# y_168 = 0.500
# y_90 = 0.500
# y_124 = 0.500
# y_2 = 0.500
# y_25 = 0.500
# y_158 = 0.500
# y_130 = 0.500
# y_44 = 0.500
# y_164 = 0.500
# y_173 = 0.500
# y_142 = 0.500
# y_28 = 0.500
# y_29 = 0.500
# y_59 = 0.500
# y_27 = 0.500
# y_110 = 0.500
# y_152 = 0.500
# y_125 = 0.500
# y_131 = 0.500
# y_196 = 0.500
# y_191 = 0.500
# y_113 = 0.500
# y_128 = 0.500
# y_35 = 0.500
# y_106 = 0.500
# y_102 = 0.500
# y_84 = 0.500
# y_179 = 0.500
# y_167 = 0.500
# y_100 = 0.500
# y_1 = 0.500
# y_13 = 0.500
# y_160 = 0.500
# y_7 = 0.500
# y_187 = 0.500
# y_198 = 0.500
# y_33 = 0.500
# y_181 = 0.500
# y_171 = 0.500
# y_149 = 0.500
# y_183 = 0.500
# y_107 = 0.500
# y_150 = 0.500
# y_186 = 0.500
# y_96 = 0.500
# y_97 = 0.500
# y_114 = 0.500
# y_134 = 0.500
# y_37 = 0.500
# y_34 = 0.500
# y_98 = 0.500
# y_54 = 0.500
# y_56 = 0.500
# y_143 = 0.500
# y_75 = 0.500
# y_180 = 0.500
# y_81 = 0.500
# y_64 = 0.500
# y_14 = 0.500
# y_19 = 0.500
# y_43 = 0.500
# y_92 = 0.500
# y_122 = 0.500
# y_123 = 0.500
# y_95 = 0.500
# y_170 = 0.500
# y_8 = 0.500
# y_60 = 0.500
# y_77 = 0.500
# y_45 = 0.500

# %% [markdown]
#  Code Branch and bound method by yourself

# %%
EPS = 1e-9

# %%
def heuristic_deg():
    deg = { n : 0 for n in Nodes }
    for edge in Edges:
        deg[edge[0]] += 1
        deg[edge[1]] += 1
    return deg

# %%
max(heuristic_deg().values())
# Out:
# 114

# %%
[x for x in heuristic_deg().items()]
# Out:
# [('72', 103),
#  ('127', 94),
#  ('66', 89),
#  ('20', 81),
#  ('153', 89),
#  ('165', 101),
#  ('55', 91),
#  ('50', 94),
#  ('192', 94),
#  ('88', 104),
#  ('185', 105),
#  ('10', 113),
#  ('200', 103),
#  ('31', 103),
#  ('11', 97),
#  ('117', 100),
#  ('148', 102),
#  ('9', 105),
#  ('63', 101),
#  ('4', 101),
#  ('115', 105),
#  ('197', 101),
#  ('89', 103),
#  ('138', 99),
#  ('118', 104),
#  ('71', 101),
#  ('57', 109),
#  ('74', 93),
#  ('177', 95),
#  ('39', 90),
#  ('172', 100),
#  ('140', 78),
#  ('53', 104),
#  ('161', 111),
#  ('94', 102),
#  ('178', 103),
#  ('85', 101),
#  ('5', 91),
#  ('139', 101),
#  ('163', 104),
#  ('155', 96),
#  ('22', 104),
#  ('62', 96),
#  ('144', 98),
#  ('78', 93),
#  ('21', 103),
#  ('61', 104),
#  ('49', 113),
#  ('105', 94),
#  ('135', 88),
#  ('141', 103),
#  ('16', 94),
#  ('154', 102),
#  ('111', 91),
#  ('176', 99),
#  ('41', 109),
#  ('184', 96),
#  ('12', 97),
#  ('175', 100),
#  ('145', 96),
#  ('151', 106),
#  ('169', 100),
#  ('101', 88),
#  ('194', 102),
#  ('30', 91),
#  ('38', 103),
#  ('48', 105),
#  ('190', 96),
#  ('17', 94),
#  ('87', 107),
#  ('65', 95),
#  ('73', 107),
#  ('32', 104),
#  ('46', 106),
#  ('195', 101),
#  ('109', 109),
#  ('79', 91),
#  ('69', 104),
#  ('58', 106),
#  ('132', 102),
#  ('99', 84),
#  ('157', 101),
#  ('26', 95),
#  ('70', 114),
#  ('67', 99),
#  ('40', 93),
#  ('162', 92),
#  ('189', 105),
#  ('166', 114),
#  ('51', 97),
#  ('112', 104),
#  ('121', 101),
#  ('136', 102),
#  ('93', 93),
#  ('3', 90),
#  ('80', 94),
#  ('120', 104),
#  ('188', 85),
#  ('15', 99),
#  ('76', 104),
#  ('83', 101),
#  ('199', 90),
#  ('24', 101),
#  ('104', 93),
#  ('108', 106),
#  ('119', 91),
#  ('82', 92),
#  ('146', 94),
#  ('159', 105),
#  ('52', 106),
#  ('36', 104),
#  ('147', 107),
#  ('42', 94),
#  ('156', 104),
#  ('6', 108),
#  ('18', 99),
#  ('193', 83),
#  ('116', 102),
#  ('91', 92),
#  ('47', 106),
#  ('68', 96),
#  ('23', 103),
#  ('103', 97),
#  ('126', 87),
#  ('133', 95),
#  ('174', 96),
#  ('129', 101),
#  ('86', 92),
#  ('137', 98),
#  ('182', 106),
#  ('168', 96),
#  ('90', 95),
#  ('124', 93),
#  ('2', 94),
#  ('25', 99),
#  ('158', 104),
#  ('130', 95),
#  ('44', 113),
#  ('164', 104),
#  ('173', 99),
#  ('142', 94),
#  ('28', 108),
#  ('29', 103),
#  ('59', 99),
#  ('27', 89),
#  ('110', 102),
#  ('152', 98),
#  ('125', 97),
#  ('131', 105),
#  ('196', 93),
#  ('191', 96),
#  ('113', 110),
#  ('128', 93),
#  ('35', 105),
#  ('106', 107),
#  ('102', 106),
#  ('84', 98),
#  ('179', 97),
#  ('167', 101),
#  ('100', 95),
#  ('1', 91),
#  ('13', 98),
#  ('160', 93),
#  ('7', 99),
#  ('187', 93),
#  ('198', 100),
#  ('33', 94),
#  ('181', 110),
#  ('171', 105),
#  ('149', 101),
#  ('183', 108),
#  ('107', 95),
#  ('150', 100),
#  ('186', 105),
#  ('96', 95),
#  ('97', 97),
#  ('114', 91),
#  ('134', 102),
#  ('37', 102),
#  ('34', 96),
#  ('98', 82),
#  ('54', 108),
#  ('56', 101),
#  ('143', 100),
#  ('75', 92),
#  ('180', 96),
#  ('81', 98),
#  ('64', 86),
#  ('14', 103),
#  ('19', 93),
#  ('43', 94),
#  ('92', 99),
#  ('122', 92),
#  ('123', 90),
#  ('95', 90),
#  ('170', 101),
#  ('8', 102),
#  ('60', 97),
#  ('77', 89),
#  ('45', 99)]

# %% [markdown]
# Warm start

# %%
from statistics import median

c = cp.get_cplex()
deg = heuristic_deg()

# Compute median of deg
med = median(deg.values())


c.start.set_start( col_status=[],
                   row_status=[],
                   col_primal=[ (1.0 if (x > med) else 0.0) for x in deg.values() ],
                   row_primal=[],
                   col_dual=[],
                   row_dual=[])

# %%
y_cons
# Out:
# {'72': docplex.mp.LinearConstraint[](y_72,LE,1),
#  '127': docplex.mp.LinearConstraint[](y_127,LE,1),
#  '66': docplex.mp.LinearConstraint[](y_66,LE,1),
#  '20': docplex.mp.LinearConstraint[](y_20,LE,1),
#  '153': docplex.mp.LinearConstraint[](y_153,LE,1),
#  '165': docplex.mp.LinearConstraint[](y_165,LE,1),
#  '55': docplex.mp.LinearConstraint[](y_55,LE,1),
#  '50': docplex.mp.LinearConstraint[](y_50,LE,1),
#  '192': docplex.mp.LinearConstraint[](y_192,LE,1),
#  '88': docplex.mp.LinearConstraint[](y_88,LE,1),
#  '185': docplex.mp.LinearConstraint[](y_185,LE,1),
#  '10': docplex.mp.LinearConstraint[](y_10,LE,1),
#  '200': docplex.mp.LinearConstraint[](y_200,LE,1),
#  '31': docplex.mp.LinearConstraint[](y_31,LE,1),
#  '11': docplex.mp.LinearConstraint[](y_11,LE,1),
#  '117': docplex.mp.LinearConstraint[](y_117,LE,1),
#  '148': docplex.mp.LinearConstraint[](y_148,LE,1),
#  '9': docplex.mp.LinearConstraint[](y_9,LE,1),
#  '63': docplex.mp.LinearConstraint[](y_63,LE,1),
#  '4': docplex.mp.LinearConstraint[](y_4,LE,1),
#  '115': docplex.mp.LinearConstraint[](y_115,LE,1),
#  '197': docplex.mp.LinearConstraint[](y_197,LE,1),
#  '89': docplex.mp.LinearConstraint[](y_89,LE,1),
#  '138': docplex.mp.LinearConstraint[](y_138,LE,1),
#  '118': docplex.mp.LinearConstraint[](y_118,LE,1),
#  '71': docplex.mp.LinearConstraint[](y_71,LE,1),
#  '57': docplex.mp.LinearConstraint[](y_57,LE,1),
#  '74': docplex.mp.LinearConstraint[](y_74,LE,1),
#  '177': docplex.mp.LinearConstraint[](y_177,LE,1),
#  '39': docplex.mp.LinearConstraint[](y_39,LE,1),
#  '172': docplex.mp.LinearConstraint[](y_172,LE,1),
#  '140': docplex.mp.LinearConstraint[](y_140,LE,1),
#  '53': docplex.mp.LinearConstraint[](y_53,LE,1),
#  '161': docplex.mp.LinearConstraint[](y_161,LE,1),
#  '94': docplex.mp.LinearConstraint[](y_94,LE,1),
#  '178': docplex.mp.LinearConstraint[](y_178,LE,1),
#  '85': docplex.mp.LinearConstraint[](y_85,LE,1),
#  '5': docplex.mp.LinearConstraint[](y_5,LE,1),
#  '139': docplex.mp.LinearConstraint[](y_139,LE,1),
#  '163': docplex.mp.LinearConstraint[](y_163,LE,1),
#  '155': docplex.mp.LinearConstraint[](y_155,LE,1),
#  '22': docplex.mp.LinearConstraint[](y_22,LE,1),
#  '62': docplex.mp.LinearConstraint[](y_62,LE,1),
#  '144': docplex.mp.LinearConstraint[](y_144,LE,1),
#  '78': docplex.mp.LinearConstraint[](y_78,LE,1),
#  '21': docplex.mp.LinearConstraint[](y_21,LE,1),
#  '61': docplex.mp.LinearConstraint[](y_61,LE,1),
#  '49': docplex.mp.LinearConstraint[](y_49,LE,1),
#  '105': docplex.mp.LinearConstraint[](y_105,LE,1),
#  '135': docplex.mp.LinearConstraint[](y_135,LE,1),
#  '141': docplex.mp.LinearConstraint[](y_141,LE,1),
#  '16': docplex.mp.LinearConstraint[](y_16,LE,1),
#  '154': docplex.mp.LinearConstraint[](y_154,LE,1),
#  '111': docplex.mp.LinearConstraint[](y_111,LE,1),
#  '176': docplex.mp.LinearConstraint[](y_176,LE,1),
#  '41': docplex.mp.LinearConstraint[](y_41,LE,1),
#  '184': docplex.mp.LinearConstraint[](y_184,LE,1),
#  '12': docplex.mp.LinearConstraint[](y_12,LE,1),
#  '175': docplex.mp.LinearConstraint[](y_175,LE,1),
#  '145': docplex.mp.LinearConstraint[](y_145,LE,1),
#  '151': docplex.mp.LinearConstraint[](y_151,LE,1),
#  '169': docplex.mp.LinearConstraint[](y_169,LE,1),
#  '101': docplex.mp.LinearConstraint[](y_101,LE,1),
#  '194': docplex.mp.LinearConstraint[](y_194,LE,1),
#  '30': docplex.mp.LinearConstraint[](y_30,LE,1),
#  '38': docplex.mp.LinearConstraint[](y_38,LE,1),
#  '48': docplex.mp.LinearConstraint[](y_48,LE,1),
#  '190': docplex.mp.LinearConstraint[](y_190,LE,1),
#  '17': docplex.mp.LinearConstraint[](y_17,LE,1),
#  '87': docplex.mp.LinearConstraint[](y_87,LE,1),
#  '65': docplex.mp.LinearConstraint[](y_65,LE,1),
#  '73': docplex.mp.LinearConstraint[](y_73,LE,1),
#  '32': docplex.mp.LinearConstraint[](y_32,LE,1),
#  '46': docplex.mp.LinearConstraint[](y_46,LE,1),
#  '195': docplex.mp.LinearConstraint[](y_195,LE,1),
#  '109': docplex.mp.LinearConstraint[](y_109,LE,1),
#  '79': docplex.mp.LinearConstraint[](y_79,LE,1),
#  '69': docplex.mp.LinearConstraint[](y_69,LE,1),
#  '58': docplex.mp.LinearConstraint[](y_58,LE,1),
#  '132': docplex.mp.LinearConstraint[](y_132,LE,1),
#  '99': docplex.mp.LinearConstraint[](y_99,LE,1),
#  '157': docplex.mp.LinearConstraint[](y_157,LE,1),
#  '26': docplex.mp.LinearConstraint[](y_26,LE,1),
#  '70': docplex.mp.LinearConstraint[](y_70,LE,1),
#  '67': docplex.mp.LinearConstraint[](y_67,LE,1),
#  '40': docplex.mp.LinearConstraint[](y_40,LE,1),
#  '162': docplex.mp.LinearConstraint[](y_162,LE,1),
#  '189': docplex.mp.LinearConstraint[](y_189,LE,1),
#  '166': docplex.mp.LinearConstraint[](y_166,LE,1),
#  '51': docplex.mp.LinearConstraint[](y_51,LE,1),
#  '112': docplex.mp.LinearConstraint[](y_112,LE,1),
#  '121': docplex.mp.LinearConstraint[](y_121,LE,1),
#  '136': docplex.mp.LinearConstraint[](y_136,LE,1),
#  '93': docplex.mp.LinearConstraint[](y_93,LE,1),
#  '3': docplex.mp.LinearConstraint[](y_3,LE,1),
#  '80': docplex.mp.LinearConstraint[](y_80,LE,1),
#  '120': docplex.mp.LinearConstraint[](y_120,LE,1),
#  '188': docplex.mp.LinearConstraint[](y_188,LE,1),
#  '15': docplex.mp.LinearConstraint[](y_15,LE,1),
#  '76': docplex.mp.LinearConstraint[](y_76,LE,1),
#  '83': docplex.mp.LinearConstraint[](y_83,LE,1),
#  '199': docplex.mp.LinearConstraint[](y_199,LE,1),
#  '24': docplex.mp.LinearConstraint[](y_24,LE,1),
#  '104': docplex.mp.LinearConstraint[](y_104,LE,1),
#  '108': docplex.mp.LinearConstraint[](y_108,LE,1),
#  '119': docplex.mp.LinearConstraint[](y_119,LE,1),
#  '82': docplex.mp.LinearConstraint[](y_82,LE,1),
#  '146': docplex.mp.LinearConstraint[](y_146,LE,1),
#  '159': docplex.mp.LinearConstraint[](y_159,LE,1),
#  '52': docplex.mp.LinearConstraint[](y_52,LE,1),
#  '36': docplex.mp.LinearConstraint[](y_36,LE,1),
#  '147': docplex.mp.LinearConstraint[](y_147,LE,1),
#  '42': docplex.mp.LinearConstraint[](y_42,LE,1),
#  '156': docplex.mp.LinearConstraint[](y_156,LE,1),
#  '6': docplex.mp.LinearConstraint[](y_6,LE,1),
#  '18': docplex.mp.LinearConstraint[](y_18,LE,1),
#  '193': docplex.mp.LinearConstraint[](y_193,LE,1),
#  '116': docplex.mp.LinearConstraint[](y_116,LE,1),
#  '91': docplex.mp.LinearConstraint[](y_91,LE,1),
#  '47': docplex.mp.LinearConstraint[](y_47,LE,1),
#  '68': docplex.mp.LinearConstraint[](y_68,LE,1),
#  '23': docplex.mp.LinearConstraint[](y_23,LE,1),
#  '103': docplex.mp.LinearConstraint[](y_103,LE,1),
#  '126': docplex.mp.LinearConstraint[](y_126,LE,1),
#  '133': docplex.mp.LinearConstraint[](y_133,LE,1),
#  '174': docplex.mp.LinearConstraint[](y_174,LE,1),
#  '129': docplex.mp.LinearConstraint[](y_129,LE,1),
#  '86': docplex.mp.LinearConstraint[](y_86,LE,1),
#  '137': docplex.mp.LinearConstraint[](y_137,LE,1),
#  '182': docplex.mp.LinearConstraint[](y_182,LE,1),
#  '168': docplex.mp.LinearConstraint[](y_168,LE,1),
#  '90': docplex.mp.LinearConstraint[](y_90,LE,1),
#  '124': docplex.mp.LinearConstraint[](y_124,LE,1),
#  '2': docplex.mp.LinearConstraint[](y_2,LE,1),
#  '25': docplex.mp.LinearConstraint[](y_25,LE,1),
#  '158': docplex.mp.LinearConstraint[](y_158,LE,1),
#  '130': docplex.mp.LinearConstraint[](y_130,LE,1),
#  '44': docplex.mp.LinearConstraint[](y_44,LE,1),
#  '164': docplex.mp.LinearConstraint[](y_164,LE,1),
#  '173': docplex.mp.LinearConstraint[](y_173,LE,1),
#  '142': docplex.mp.LinearConstraint[](y_142,LE,1),
#  '28': docplex.mp.LinearConstraint[](y_28,LE,1),
#  '29': docplex.mp.LinearConstraint[](y_29,LE,1),
#  '59': docplex.mp.LinearConstraint[](y_59,LE,1),
#  '27': docplex.mp.LinearConstraint[](y_27,LE,1),
#  '110': docplex.mp.LinearConstraint[](y_110,LE,1),
#  '152': docplex.mp.LinearConstraint[](y_152,LE,1),
#  '125': docplex.mp.LinearConstraint[](y_125,LE,1),
#  '131': docplex.mp.LinearConstraint[](y_131,LE,1),
#  '196': docplex.mp.LinearConstraint[](y_196,LE,1),
#  '191': docplex.mp.LinearConstraint[](y_191,LE,1),
#  '113': docplex.mp.LinearConstraint[](y_113,LE,1),
#  '128': docplex.mp.LinearConstraint[](y_128,LE,1),
#  '35': docplex.mp.LinearConstraint[](y_35,LE,1),
#  '106': docplex.mp.LinearConstraint[](y_106,LE,1),
#  '102': docplex.mp.LinearConstraint[](y_102,LE,1),
#  '84': docplex.mp.LinearConstraint[](y_84,LE,1),
#  '179': docplex.mp.LinearConstraint[](y_179,LE,1),
#  '167': docplex.mp.LinearConstraint[](y_167,LE,1),
#  '100': docplex.mp.LinearConstraint[](y_100,LE,1),
#  '1': docplex.mp.LinearConstraint[](y_1,LE,1),
#  '13': docplex.mp.LinearConstraint[](y_13,LE,1),
#  '160': docplex.mp.LinearConstraint[](y_160,LE,1),
#  '7': docplex.mp.LinearConstraint[](y_7,LE,1),
#  '187': docplex.mp.LinearConstraint[](y_187,LE,1),
#  '198': docplex.mp.LinearConstraint[](y_198,LE,1),
#  '33': docplex.mp.LinearConstraint[](y_33,LE,1),
#  '181': docplex.mp.LinearConstraint[](y_181,LE,1),
#  '171': docplex.mp.LinearConstraint[](y_171,LE,1),
#  '149': docplex.mp.LinearConstraint[](y_149,LE,1),
#  '183': docplex.mp.LinearConstraint[](y_183,LE,1),
#  '107': docplex.mp.LinearConstraint[](y_107,LE,1),
#  '150': docplex.mp.LinearConstraint[](y_150,LE,1),
#  '186': docplex.mp.LinearConstraint[](y_186,LE,1),
#  '96': docplex.mp.LinearConstraint[](y_96,LE,1),
#  '97': docplex.mp.LinearConstraint[](y_97,LE,1),
#  '114': docplex.mp.LinearConstraint[](y_114,LE,1),
#  '134': docplex.mp.LinearConstraint[](y_134,LE,1),
#  '37': docplex.mp.LinearConstraint[](y_37,LE,1),
#  '34': docplex.mp.LinearConstraint[](y_34,LE,1),
#  '98': docplex.mp.LinearConstraint[](y_98,LE,1),
#  '54': docplex.mp.LinearConstraint[](y_54,LE,1),
#  '56': docplex.mp.LinearConstraint[](y_56,LE,1),
#  '143': docplex.mp.LinearConstraint[](y_143,LE,1),
#  '75': docplex.mp.LinearConstraint[](y_75,LE,1),
#  '180': docplex.mp.LinearConstraint[](y_180,LE,1),
#  '81': docplex.mp.LinearConstraint[](y_81,LE,1),
#  '64': docplex.mp.LinearConstraint[](y_64,LE,1),
#  '14': docplex.mp.LinearConstraint[](y_14,LE,1),
#  '19': docplex.mp.LinearConstraint[](y_19,LE,1),
#  '43': docplex.mp.LinearConstraint[](y_43,LE,1),
#  '92': docplex.mp.LinearConstraint[](y_92,LE,1),
#  '122': docplex.mp.LinearConstraint[](y_122,LE,1),
#  '123': docplex.mp.LinearConstraint[](y_123,LE,1),
#  '95': docplex.mp.LinearConstraint[](y_95,LE,1),
#  '170': docplex.mp.LinearConstraint[](y_170,LE,1),
#  '8': docplex.mp.LinearConstraint[](y_8,LE,1),
#  '60': docplex.mp.LinearConstraint[](y_60,LE,1),
#  '77': docplex.mp.LinearConstraint[](y_77,LE,1),
#  '45': docplex.mp.LinearConstraint[](y_45,LE,1)}

# %%
import numpy as np

EPS = 1e-8

def is_int(elem):
    return np.isclose(elem,np.round(elem), atol=EPS)

def is_int_list(elems):
    """Return true if
    all elements in iterable arg elems
    are close to integers
    """
    res = True
    for elem in elems:
        if not np.isclose(elem,np.round(elem), atol=EPS):
            res = False
            break
    return res


x = [1.0, 0.999999999999999, 2.00000000000001]
y = [1.0002]
is_int_list(x), is_int_list(y)
# Out:
# (True, False)

# %%
from heapq import heappush, heappop

class PriorityQueue:
    """Implemets fast realisation
    of priority queue in terms of 
    tasks
    """
    def __init__(self):
        self.pq = []                         # list of entries arranged in a heap
        self.entry_finder = {}               # mapping of tasks to entries
        self.REMOVED = '<removed-task>'      # placeholder for a removed task

    def add_task(self,task, priority=0):
        'Add a new task or update the priority of an existing task'
        if task in self.entry_finder:
            self.remove_task(task)
        entry = [priority, task]
        self.entry_finder[task] = entry
        heappush(self.pq, entry)

    def remove_task(self,task):
        'Mark an existing task as REMOVED.  Raise KeyError if not found.'
        entry = self.entry_finder.pop(task)
        entry[-1] = REMOVED

    def pop_task_and_priority(self):
        'Remove and return the lowest priority task and the priority. Raise KeyError if empty.'
        while self.pq:
            priority, task = heappop(self.pq)
            if task is not self.REMOVED:
                del self.entry_finder[task]
                return priority, task
        raise KeyError('pop from an empty priority queue')
        
    def get_list_copy(self):
        'Return copy of all task list'
        return self.pq.copy()
    
    def __nonzero__(self):
        'Return value in conditional statements'
        return not not self.pq 

pq = PriorityQueue()
pq.add_task((3,3,3,3), 3)
pq.add_task((2,2), 2)
pq.add_task((1010,1010), 10)

print(pq.get_list_copy())
print(
pq.pop_task_and_priority(),pq.pop_task_and_priority(),pq.pop_task_and_priority()
)
# Out:
# [[2, (2, 2)], [3, (3, 3, 3, 3)], [10, (1010, 1010)]]
# (2, (2, 2)) (3, (3, 3, 3, 3)) (10, (1010, 1010))

# %%
class QueueCluque:
    """Special Priority Queue
    for Max Clique Problem.
    Return the biggest node in
    search tree. 
    In future:
    If it's several nodes
    which have simular truncated values but
    one is pure integer 
        - return integer one
    """
    
    def __init__(self):
        self.pq = PriorityQueue()
        
    def push(key,value):
        """Push nodes with 
        args:
            key - Objective Funct value 
            value - arguments of Objective Funct
        """

# %% [markdown]
# Branch and Bounds method for max clique issue:

# %%
def get_node_index_to_branch(elems):
    """Choose most apropriate 
    elem from elems to make 
    the branch.
    Return index of most appropriate element
    from list or -1 if all elements is integers
    """
    i = -1
    val = 1.0
    for j, elem in enumerate(elems):
        val_ = abs(elem - np.round(elem))
        if EPS < val_ < val:
            i = j
            val = val_
            
    return i
            
x = [1.0, 0.999999999999999, 2.00000000000001]
y = [1.0, 0.999999999999999, 1.0001, 1.000001,2.00000000000001]
print(get_node_index_to_branch(x))  
print(get_node_index_to_branch(y))
# Out:
# -1
# 3

# %% [markdown]
# Add and remove constraints test

# %%
from docplex.mp.model import Model

mod = Model(name='Test')

v = [mod.continuous_var(name= 'y_{0}'.format(i)) for i in [1,2,3] ]
constr = mod.add_constraint(v[0] == 1)
print(constr)
print("Constraints count before ", mod.number_of_linear_constraints)
mod.remove_constraint(constr)
print("Constraints count after ",  mod.number_of_linear_constraints)

#[x for x in dir(cp) ]
# Out:
# y_1 == 1
# Constraints count before  1
# Constraints count after  0

# %%
def BnBMaxClique():
    """Compute optimal solutuon
    for max clique problem using
    Branch and bounds method 
    """
    # CP must be CPLEX model
    # inicialized for MaxClique
    # problem
    global cp
    global y
    
    nodes = PriorityQueue()
    sol = cp.solve()
    best_objective = (0,0)
    
    obj = get_objective_value()
    values = sol.get_all_values()
    
    # Put sollution into queue.
    nodes.add_task(priority=obj, task=values)
    
    while nodes:
        obj, values = nodes.pop_taskp_task()
        i = get_node_index_to_branch(values)
        
        # If it's integer solution
        if i == -1:
            # Cut all not in solutions that's worse
            # then founded int sol
            obj = np.round(obj)
            for node in nodes.get_list_copy():
                # There is only not integer 
                # solutions in nodes => 
                # truncate is appropriate
                
                # If upper bound of non int solution
                # isn't more than founded solution 
                # objective
                if obj >= np.trunc(node[0]):
                    # Remove it from nodes queue
                    nodes.remove_task(node[1])
            # Remember best solution
            if best_objective[0] < obj:
                best_objective = (obj,values)
        
        else:
            # Branch it!
            for ind in [0,1]:
                # Set i-th constraint to val 
                constr = cp.add_constraint(y[i] == ind)
                
                # Remove it  from the model
                cp.remove_constraint(constr)
